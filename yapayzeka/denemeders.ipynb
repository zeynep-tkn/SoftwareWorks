# %%
import numpy as np 
import pandas as pd
dataframe=pd.read_csv('../yapayzeka/heart-disease.csv')

# %%
dataframe.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
x=dataframe.drop("target",axis=1)
y=dataframe["target"]

# %%
x.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal
# 0   0     1
# 1   0     2
# 2   0     2
# 3   0     2
# 4   0     2

# %%
y.head(),y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 303 entries, 0 to 302
# Series name: target
# Non-Null Count  Dtype
# --------------  -----
# 303 non-null    int64
# dtypes: int64(1)
# memory usage: 2.5 KB
# (0    1
#  1    1
#  2    1
#  3    1
#  4    1
#  Name: target, dtype: int64,
#  None)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((242, 13), (61, 13), (242,), (61,))

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearnçsvm import SVC,LinearSVr
clf=RandomForestClassifier(n_estimators=120,max_depth=8)
clf1=SVC(kernel="poly")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 2
#       1 from sklearn.ensemble import RandomForestClassifier
# ----> 2 from sklearnçsvm import SVC,LinearSVr
#       3 clf=RandomForestClassifier(n_estimators=120,max_depth=8)
#       4 clf1=SVC(kernel="poly")
#
# ModuleNotFoundError: No module named 'sklearnçsvm'

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC,LinearSVr
clf=RandomForestClassifier(n_estimators=120,max_depth=8)
clf1=SVC(kernel="poly")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[8], line 2
#       1 from sklearn.ensemble import RandomForestClassifier
# ----> 2 from sklearn.svm import SVC,LinearSVr
#       3 clf=RandomForestClassifier(n_estimators=120,max_depth=8)
#       4 clf1=SVC(kernel="poly")
#
# ImportError: cannot import name 'LinearSVr' from 'sklearn.svm' (C:\ProgramData\anaconda3\Lib\site-packages\sklearn\svm\__init__.py)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC,LinearSVR
clf=RandomForestClassifier(n_estimators=120,max_depth=8)
clf1=SVC(kernel="poly")

# %%
clf.get_params(),clf1.get_params()
# Out:
# ({'bootstrap': True,
#   'ccp_alpha': 0.0,
#   'class_weight': None,
#   'criterion': 'gini',
#   'max_depth': 8,
#   'max_features': 'sqrt',
#   'max_leaf_nodes': None,
#   'max_samples': None,
#   'min_impurity_decrease': 0.0,
#   'min_samples_leaf': 1,
#   'min_samples_split': 2,
#   'min_weight_fraction_leaf': 0.0,
#   'n_estimators': 120,
#   'n_jobs': None,
#   'oob_score': False,
#   'random_state': None,
#   'verbose': 0,
#   'warm_start': False},
#  {'C': 1.0,
#   'break_ties': False,
#   'cache_size': 200,
#   'class_weight': None,
#   'coef0': 0.0,
#   'decision_function_shape': 'ovr',
#   'degree': 3,
#   'gamma': 'scale',
#   'kernel': 'poly',
#   'max_iter': -1,
#   'probability': False,
#   'random_state': None,
#   'shrinking': True,
#   'tol': 0.001,
#   'verbose': False})

# %%
clf.fit(x=x_train, y=y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 clf.fit(x=x_train, y=y_train)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# TypeError: BaseForest.fit() got an unexpected keyword argument 'x'

# %%
clf1.fit(x=x_train, y=y_train)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 clf1.fit(x=x_train, y=y_train)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1144     estimator._validate_params()
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# TypeError: BaseLibSVM.fit() got an unexpected keyword argument 'x'

# %%
clf.fit(X=x_train, y=y_train)
# Out:
# RandomForestClassifier(max_depth=8, n_estimators=120)

# %%
clf1.fit(X=x_train, y=y_train)
# Out:
# SVC(kernel='poly')

# %%
y_preds= clf.predict(X=x_test)
y_preds= clf1.predict(X=x_test)

# %%
y_preds= clf.predict(X=x_test)
y_preds_1= clf1.predict(X=x_test)

# %%
train_acc = clf.score(X=x_train, y=y_train)
train_acc
# Out:
# 1.0

# %%
from ipywidgets import Image
from io import StringIO
import pydotplus
from sklearn.tree import export_graphviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 3
#       1 from ipywidgets import Image
#       2 from io import StringIO
# ----> 3 import pydotplus
#       4 from sklearn.tree import export_graphviz
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
conda install pydotplus
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - pydotplus
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2023.12.12 |       haa95532_0         127 KB
#     cairo-1.16.0               |       haedb8bc_5         1.9 MB
#     certifi-2023.11.17         |  py311haa95532_0         160 KB
#     expat-2.5.0                |       hd77b12b_0         225 KB
#     fontconfig-2.14.1          |       h9c4af85_2         198 KB
#     fribidi-1.0.10             |       h62dcd97_0          63 KB
#     getopt-win32-0.1           |       h2bbff1b_0          19 KB
#     graphite2-1.3.14           |       hd77b12b_1          91 KB
#     graphviz-2.50.0            |       hdb8b0d4_0         903 KB
# ...

# %%
from ipywidgets import Image
from io import StringIO
import pydotplus
from sklearn.tree import export_graphviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 3
#       1 from ipywidgets import Image
#       2 from io import StringIO
# ----> 3 import pydotplus
#       4 from sklearn.tree import export_graphviz
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
conda install pydotplus
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - pydotplus
#
#
# The following NEW packages will be INSTALLED:
#
#   cairo              pkgs/main/win-64::cairo-1.16.0-haedb8bc_5
#   expat              pkgs/main/win-64::expat-2.5.0-hd77b12b_0
#   fontconfig         pkgs/main/win-64::fontconfig-2.14.1-h9c4af85_2
#   fribidi            pkgs/main/win-64::fribidi-1.0.10-h62dcd97_0
#   getopt-win32       pkgs/main/win-64::getopt-win32-0.1-h2bbff1b_0
#   graphite2          pkgs/main/win-64::graphite2-1.3.14-hd77b12b_1
#   graphviz           pkgs/main/win-64::graphviz-2.50.0-hdb8b0d4_0
#   gts                pkgs/main/win-64::gts-0.7.6-h63ab5a1_3
#   harfbuzz           pkgs/main/win-64::harfbuzz-4.3.0-hb646838_1
#   libgd              pkgs/main/win-64::libgd-2.3.3-ha43c60c_1
#   pango              pkgs/main/win-64::pango-1.50.7-h78c2152_0
# ...

# %%
from ipywidgets import Image
from io import StringIO
import pydotplus
from sklearn.tree import export_graphviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[23], line 3
#       1 from ipywidgets import Image
#       2 from io import StringIO
# ----> 3 import pydotplus
#       4 from sklearn.tree import export_graphviz
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
conda install ipywidgets
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.08.22-haa95532_0 --> 2023.12.12-haa95532_0
#   certifi                         2023.7.22-py311haa95532_0 --> 2023.11.17-py311haa95532_0
#   openssl                                 3.0.10-h2bbff1b_2 --> 3.0.12-h2bbff1b_0
#
#
#
# ...
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#
#
#
# ...

# %%
from ipywidgets import Image
from io import StringIO
import pydotplus
from sklearn.tree import export_graphviz
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[25], line 3
#       1 from ipywidgets import Image
#       2 from io import StringIO
# ----> 3 import pydotplus
#       4 from sklearn.tree import export_graphviz
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
conda install ipywidgets
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.08.22-haa95532_0 --> 2023.12.12-haa95532_0
#   certifi                         2023.7.22-py311haa95532_0 --> 2023.11.17-py311haa95532_0
#   openssl                                 3.0.10-h2bbff1b_2 --> 3.0.12-h2bbff1b_0
#
#
#
# ...
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.7.4
#   latest version: 23.11.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.11.0
#
#
#
# ...

# %%
conda install pydotplus
conda install graphviz
# Out:
#   Cell In[29], line 1
#     conda install ipywidgets
#           ^
# SyntaxError: invalid syntax

# %%
conda install ipywidgets
conda install pydotplus
conda install graphviz
# Out:
#   Cell In[30], line 1
#     conda install ipywidgets
#           ^
# SyntaxError: invalid syntax

# %%
from ipywidgets import Image
from io import StringIO
import pydotplus
from sklearn.tree import export_graphviz

d_tree110 = clf.estimators_[111]
dot_data1 = StringIO()
export_graphviz(d_tree110, faature_names = x.columns,
               out_file = dot_data1, filled = True, rounded=True)
graph = pydotplus.graph_from_dot_data(dot_data1.getvalue())
graph.write_png('clf_110b.png')
Image(value=graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[32], line 3
#       1 from ipywidgets import Image
#       2 from io import StringIO
# ----> 3 import pydotplus
#       4 from sklearn.tree import export_graphviz
#       6 d_tree110 = clf.estimators_[111]
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
from ipywidgets import Image
from io import StringIO
import pydotplus
from sklearn.tree import export_graphviz

d_tree110 = clf.estimators_[111]
dot_data1 = StringIO()
export_graphviz(d_tree110, faature_names = X.columns,
               out_file = dot_data1, filled = True, rounded=True)
graph = pydotplus.graph_from_dot_data(dot_data1.getvalue())
graph.write_png('clf_110b.png')
Image(value=graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[33], line 3
#       1 from ipywidgets import Image
#       2 from io import StringIO
# ----> 3 import pydotplus
#       4 from sklearn.tree import export_graphviz
#       6 d_tree110 = clf.estimators_[111]
#
# ModuleNotFoundError: No module named 'pydotplus'

# %%
conda install pydotplus
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\anaconda3
#
#   added / updated specs:
#     - pydotplus
#
#
# The following NEW packages will be INSTALLED:
#
#   cairo              pkgs/main/win-64::cairo-1.16.0-haedb8bc_5
#   expat              pkgs/main/win-64::expat-2.5.0-hd77b12b_0
#   fontconfig         pkgs/main/win-64::fontconfig-2.14.1-h9c4af85_2
#   fribidi            pkgs/main/win-64::fribidi-1.0.10-h62dcd97_0
#   getopt-win32       pkgs/main/win-64::getopt-win32-0.1-h2bbff1b_0
#   graphite2          pkgs/main/win-64::graphite2-1.3.14-hd77b12b_1
#   graphviz           pkgs/main/win-64::graphviz-2.50.0-hdb8b0d4_0
#   gts                pkgs/main/win-64::gts-0.7.6-h63ab5a1_3
#   harfbuzz           pkgs/main/win-64::harfbuzz-4.3.0-hb646838_1
#   libgd              pkgs/main/win-64::libgd-2.3.3-ha43c60c_1
#   pango              pkgs/main/win-64::pango-1.50.7-h78c2152_0
# ...

# %%
train_acc1 = clf1.score(X=x_train, y=y_train)

# %%
train_acc,train_acc1
# Out:
# (1.0, 0.6942148760330579)

# %%
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score
print(classification_report(y_test, y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.84      0.81        25
#            1       0.88      0.83      0.86        36
#
#     accuracy                           0.84        61
#    macro avg       0.83      0.84      0.83        61
# weighted avg       0.84      0.84      0.84        61

# %%
print(classification_report(y_test, _1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 print(classification_report(y_test, _1))
#
# NameError: name '_1' is not defined

# %%
print(classification_report(y_test,y_preds_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.56      0.61        25
#            1       0.72      0.81      0.76        36
#
#     accuracy                           0.70        61
#    macro avg       0.70      0.68      0.69        61
# weighted avg       0.70      0.70      0.70        61

# %%
conf_mat = confusion_matrix(y_test, y_preds)

# %%
conf_mat
# Out:
# array([[21,  4],
#        [ 6, 30]], dtype=int64)

# %%
conf_mat1 = confusion_matrix(y_test, y_preds_1)

# %%
import seaborn as sns
sns.heatmap(conf_mat, annot=True)
# Out:
# <Axes: >

# %%
import seaborn as sns
sns.heatmap(conf_mat, annot=True)
# Out:
# <Axes: >
